# %% [markdown]
# # Brain Tumor Detection by using MRI Images🧠🩺

# %%
import numpy as np
import cv2
import os
import matplotlib.pyplot as plt
import tensorflow as tf
# %matplotlib inline

# %%
from keras.models import load_model
model = load_model('best_models/fine_tuned')

# %%
from keras.preprocessing import image

new_img = image.load_img('test/yes_tumor (5).jpg', target_size=(224, 224))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
img = img/255
plt.imshow(img[0])
plt.axis('off')
pred = model.predict(img)
print(pred)
if pred[0]>0.966:
    print("Having Tumor")
else:
    print("Not Having Tumor")
# Out:
# [[0.9697934]]
# Having Tumor

# %%
new_img = image.load_img('test/no_tumor (5).jpg', target_size=(224, 224))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
img = img/255
plt.imshow(img[0])
plt.axis('off')
pred = model.predict(img)
print(pred)
if pred[0]>0.966:
    print("Having Tumor")
else:
    print("Not Having Tumor")
# Out:
# [[0.96540034]]
# Not Having Tumor

# %% [markdown]
# ### From testing the images, we come to know that VGG-16(fine-tuned) shows correct output for images (Having Tumor and Not Having Tumor)

# %%
new_img = image.load_img('test/yes_tumor (3).jpg', target_size=(224, 224))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
img = img/255
plt.imshow(img[0])
plt.axis('off')
pred = model.predict(img)
print(pred)
if pred[0]>0.966:
    print("Having Tumor")
else:
    print("Not Having Tumor")
# Out:
# [[0.99886835]]
# Having Tumor

# %%
new_img = image.load_img('test/no_tumor (2).jpg', target_size=(224, 224))
img = image.img_to_array(new_img)
img = np.expand_dims(img, axis=0)
img = img/255
plt.imshow(img[0])
plt.axis('off')
pred = model.predict(img)
print(pred)
if pred[0]>0.966:
    print("Having Tumor")
else:
    print("Not Having Tumor")
# Out:
# [[0.96599656]]
# Not Having Tumor
